# %% [markdown]
# # DCGAN on Bricks Dataset

# %% [markdown]
# **The notebook has been adapted from the notebook provided in David Foster's Generative Deep Learning, 2nd Edition.**
#
# - Book: [Amazon](https://www.amazon.com/Generative-Deep-Learning-Teaching-Machines/dp/1098134184/ref=sr_1_1?keywords=generative+deep+learning%2C+2nd+edition&qid=1684708209&sprefix=generative+de%2Caps%2C93&sr=8-1)
# - Original notebook (tensorflow and keras): [Github](https://github.com/davidADSP/Generative_Deep_Learning_2nd_Edition/blob/main/notebooks/04_gan/01_dcgan/dcgan.ipynb), Lincense: Apache-2.0
# - Dataset: [Kaggle](https://www.kaggle.com/datasets/joosthazelzet/lego-brick-images)

# %% [markdown]
# ## NOTE: This notebook is still in progress, there're many bugs here

# %%
import numpy as np
import time
from collections import defaultdict
from IPython import display

import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import utils
from tensorflow.keras import metrics as Metrics

import jax
import jax.numpy as jnp

import flax.linen as nn
from flax.training import train_state

import optax
from clu import metrics

# %% [markdown]
# ## 0. Train Parameters

# %%
DATA_DIR = '../../data/Lego/dataset'
IMAGE_SIZE = 64
CHANNELS = 1
BATCH_SIZE = 128
Z_DIM = 100
NOISE_PARAM = 0.1
EPOCHS = 100
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.999
LR = 2e-4

# %% [markdown]
# ## 1. Prepare dataset

# %%
# Convert images to tensors normalize them
def preprocess(img):
    img = (tf.cast(img, tf.float32) - 127.5) / 127.5
    return img

# Load lego dataset from directory
def get_dataset():
    train_ds = utils.image_dataset_from_directory(
        directory=DATA_DIR,
        labels=None,
        color_mode='grayscale',
        image_size=(IMAGE_SIZE, IMAGE_SIZE),
        batch_size=None,
        shuffle=True,
        seed=1024,
        interpolation='bilinear',
    ) 

    train_ds = train_ds.map(lambda sample: preprocess(sample))
    train_ds = train_ds.repeat(EPOCHS).shuffle(1024)
    train_ds = train_ds.batch(BATCH_SIZE, drop_remainder=True).prefetch(1)

    return train_ds

# %%
def display_imgs(imgs):
    plt.figure(figsize=(16, 3))
    for i in range(8):
        ax = plt.subplot(1, 8, i+1)
        ax.imshow(imgs[i], cmap='gray')
        ax.axis('off')
    plt.show()

# plot training records
def show_records(history):
    plt.figure(figsize=(16, 3))
    for i, key in enumerate(history):
        ax = plt.subplot(1, len(history), i+1)
        ax.plot(history[key])
        ax.set_title(key)
    plt.show()

# %%
check_ds = get_dataset()
check_sample = next(iter(check_ds))
print(check_sample.shape)
display_imgs(check_sample)
# Out:
# Found 40000 files belonging to 1 classes.
# (128, 64, 64, 1)

# %% [markdown]
# ## 2. Building GAN

# %%
class Discriminator(nn.Module):

    channel_list: tuple = (64, 128, 256, 512)
    
    @nn.compact
    def __call__(self, x, train:bool):

        # Convolutional layers
        for i, features in enumerate(self.channel_list):
            x = self.conv_block(x, features, i, train)

        # Output layers
        x = nn.Conv(features=1, kernel_size=(4, 4), strides=1, 
                    padding='valid', use_bias=False)(x)
        x = nn.sigmoid(x)
        x = x.reshape(-1, 1)
        return x

    # Downsampling convolution block
    def conv_block(self, x, out_features, use_bn, train:bool):
        x = nn.Conv(features=out_features, kernel_size=(4, 4), strides=2,
                    padding='same', use_bias=False)(x)
        
        if use_bn:
            x = nn.BatchNorm(use_running_average=not train, momentum=0.9)(x)
        x = nn.leaky_relu(x, negative_slope=0.2)
        x = nn.Dropout(rate=0.3, deterministic=not train)(x)
        return x

net_D = Discriminator()
print(net_D.tabulate(jax.random.PRNGKey(0), jnp.ones((1, 64, 64, 1)), train=False, console_kwargs={'width': 120}))
# Out:
#                                                  Discriminator Summary
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓
# ┃ path        ┃ module        ┃ inputs               ┃ outputs              ┃ params              ┃ batch_stats        ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩
# │             │ Discriminator │ - float32[1,64,64,1] │ float32[1,1]         │                     │                    │
# │             │               │ - train: False       │                      │                     │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Conv_0      │ Conv          │ float32[1,64,64,1]   │ float32[1,32,32,64]  │ kernel:             │                    │
# │             │               │                      │                      │ float32[4,4,1,64]   │                    │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 1,024 (4.1 KB)      │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Dropout_0   │ Dropout       │ float32[1,32,32,64]  │ float32[1,32,32,64]  │                     │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Conv_1      │ Conv          │ float32[1,32,32,64]  │ float32[1,16,16,128] │ kernel:             │                    │
# │             │               │                      │                      │ float32[4,4,64,128] │                    │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 131,072 (524.3 KB)  │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ BatchNorm_0 │ BatchNorm     │ float32[1,16,16,128] │ float32[1,16,16,128] │ bias: float32[128]  │ mean: float32[128] │
# │             │               │                      │                      │ scale: float32[128] │ var: float32[128]  │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 256 (1.0 KB)        │ 256 (1.0 KB)       │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Dropout_1   │ Dropout       │ float32[1,16,16,128] │ float32[1,16,16,128] │                     │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Conv_2      │ Conv          │ float32[1,16,16,128] │ float32[1,8,8,256]   │ kernel:             │                    │
# │             │               │                      │                      │ float32[4,4,128,25… │                    │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 524,288 (2.1 MB)    │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ BatchNorm_1 │ BatchNorm     │ float32[1,8,8,256]   │ float32[1,8,8,256]   │ bias: float32[256]  │ mean: float32[256] │
# │             │               │                      │                      │ scale: float32[256] │ var: float32[256]  │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 512 (2.0 KB)        │ 512 (2.0 KB)       │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Dropout_2   │ Dropout       │ float32[1,8,8,256]   │ float32[1,8,8,256]   │                     │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Conv_3      │ Conv          │ float32[1,8,8,256]   │ float32[1,4,4,512]   │ kernel:             │                    │
# │             │               │                      │                      │ float32[4,4,256,51… │                    │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 2,097,152 (8.4 MB)  │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ BatchNorm_2 │ BatchNorm     │ float32[1,4,4,512]   │ float32[1,4,4,512]   │ bias: float32[512]  │ mean: float32[512] │
# │             │               │                      │                      │ scale: float32[512] │ var: float32[512]  │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 1,024 (4.1 KB)      │ 1,024 (4.1 KB)     │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Dropout_3   │ Dropout       │ float32[1,4,4,512]   │ float32[1,4,4,512]   │                     │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │ Conv_4      │ Conv          │ float32[1,4,4,512]   │ float32[1,1,1,1]     │ kernel:             │                    │
# │             │               │                      │                      │ float32[4,4,512,1]  │                    │
# │             │               │                      │                      │                     │                    │
# │             │               │                      │                      │ 8,192 (32.8 KB)     │                    │
# ├─────────────┼───────────────┼──────────────────────┼──────────────────────┼─────────────────────┼────────────────────┤
# │             │               │                      │                Total │ 2,763,520 (11.1 MB) │ 1,792 (7.2 KB)     │
# └─────────────┴───────────────┴──────────────────────┴──────────────────────┴─────────────────────┴────────────────────┘
#
#                                          Total Parameters: 2,765,312 (11.1 MB)

# %%
class Generator(nn.Module):
    z_dim: int
    channel_list:tuple = (512, 256, 128, 64)

    @nn.compact
    def __call__(self, x, train:bool):
        x = x.reshape(x.shape[0], 1, 1, x.shape[1])

        # Transpose convolution layers
        for i, features in enumerate(self.channel_list):
            strides = 2 if i else 1
            padding = 'SAME' if i else 'VALID'
            x = self.transconv_block(x, features, strides, padding, train)

        # Output layers
        x = nn.ConvTranspose(features=CHANNELS, kernel_size=(4, 4), strides=(2, 2),
                             padding='SAME', use_bias=False)(x)
        x = nn.tanh(x)
        return x
        

    def transconv_block(self, x, out_features, strides, padding:str, train:bool):
        x = nn.ConvTranspose(features=out_features, kernel_size=(4, 4), strides=(strides, strides),
                             padding=padding, use_bias=False)(x)
        x = nn.BatchNorm(use_running_average=not train, momentum=0.9)(x)
        x = nn.leaky_relu(x, negative_slope=0.2)
        return x

netG = Generator(Z_DIM)
print(netG.tabulate(jax.random.PRNGKey(0), jnp.ones((1, Z_DIM)), train=False, console_kwargs={'width': 120}))
# Out:
#                                                    Generator Summary
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓
# ┃ path            ┃ module        ┃ inputs             ┃ outputs            ┃ params              ┃ batch_stats        ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩
# │                 │ Generator     │ - float32[1,100]   │ float32[1,64,64,1] │                     │                    │
# │                 │               │ - train: False     │                    │                     │                    │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ ConvTranspose_0 │ ConvTranspose │ float32[1,1,1,100] │ float32[1,4,4,512] │ kernel:             │                    │
# │                 │               │                    │                    │ float32[4,4,100,51… │                    │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 819,200 (3.3 MB)    │                    │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ BatchNorm_0     │ BatchNorm     │ float32[1,4,4,512] │ float32[1,4,4,512] │ bias: float32[512]  │ mean: float32[512] │
# │                 │               │                    │                    │ scale: float32[512] │ var: float32[512]  │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 1,024 (4.1 KB)      │ 1,024 (4.1 KB)     │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ ConvTranspose_1 │ ConvTranspose │ float32[1,4,4,512] │ float32[1,8,8,256] │ kernel:             │                    │
# │                 │               │                    │                    │ float32[4,4,512,25… │                    │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 2,097,152 (8.4 MB)  │                    │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ BatchNorm_1     │ BatchNorm     │ float32[1,8,8,256] │ float32[1,8,8,256] │ bias: float32[256]  │ mean: float32[256] │
# │                 │               │                    │                    │ scale: float32[256] │ var: float32[256]  │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 512 (2.0 KB)        │ 512 (2.0 KB)       │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ ConvTranspose_2 │ ConvTranspose │ float32[1,8,8,256] │ float32[1,16,16,1… │ kernel:             │                    │
# │                 │               │                    │                    │ float32[4,4,256,12… │                    │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 524,288 (2.1 MB)    │                    │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ BatchNorm_2     │ BatchNorm     │ float32[1,16,16,1… │ float32[1,16,16,1… │ bias: float32[128]  │ mean: float32[128] │
# │                 │               │                    │                    │ scale: float32[128] │ var: float32[128]  │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 256 (1.0 KB)        │ 256 (1.0 KB)       │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ ConvTranspose_3 │ ConvTranspose │ float32[1,16,16,1… │ float32[1,32,32,6… │ kernel:             │                    │
# │                 │               │                    │                    │ float32[4,4,128,64] │                    │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 131,072 (524.3 KB)  │                    │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ BatchNorm_3     │ BatchNorm     │ float32[1,32,32,6… │ float32[1,32,32,6… │ bias: float32[64]   │ mean: float32[64]  │
# │                 │               │                    │                    │ scale: float32[64]  │ var: float32[64]   │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 128 (512 B)         │ 128 (512 B)        │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │ ConvTranspose_4 │ ConvTranspose │ float32[1,32,32,6… │ float32[1,64,64,1] │ kernel:             │                    │
# │                 │               │                    │                    │ float32[4,4,64,1]   │                    │
# │                 │               │                    │                    │                     │                    │
# │                 │               │                    │                    │ 1,024 (4.1 KB)      │                    │
# ├─────────────────┼───────────────┼────────────────────┼────────────────────┼─────────────────────┼────────────────────┤
# │                 │               │                    │              Total │ 3,574,656 (14.3 MB) │ 1,920 (7.7 KB)     │
# └─────────────────┴───────────────┴────────────────────┴────────────────────┴─────────────────────┴────────────────────┘
#
#                                          Total Parameters: 3,576,576 (14.3 MB)

# %% [markdown]
# ## 3. Functions for `TrainState`

# %%
from typing import Any

# adding batch_stats and dropout keys to the properities of the class
class TrainState(train_state.TrainState):
    batch_stats: Any # for batch normalization layers
    key: jax.random.KeyArray = None # for dropout layers


# funtion to create a train state for modules
def create_train_state(module, init_array, 
                       params_key, dropout_key, 
                       learning_rate, train=False):
    """
    module: flax module
    init_array: jax.numpy.ones(shape=module_input_shape)
    param_key, dropout_key: jax.random.PRNGkey(0)
    """

    # Initialize the model with initialization array
    variables = module.init(params_key, init_array, train=False)
    params = variables['params']
    batch_stats = variables['batch_stats']

    # Create an optimizer
    tx = optax.adam(learning_rate=learning_rate, b1=ADAM_BETA_1, b2=ADAM_BETA_2)

    return TrainState.create(
            apply_fn=module.apply,
            params=params,
            batch_stats=batch_stats,
            key=dropout_key,
            tx=tx
            )

# %% [markdown]
# ## 4. Train step functions

# %%
# Loss function

@jax.vmap
def bce_loss(logit, label):
    return jnp.maximum(logit, 0) - logit * label + jnp.log(1 + jnp.exp(-jnp.abs(logit)))

# %% [markdown]
# ## 5. Load dataset and initialze the `TrainState` for both nets

# %%
train_ds = get_dataset()

tf.random.set_seed(10)

root_key = jax.random.PRNGKey(0)
d_param_key, g_param_key, dropout_key = jax.random.split(key=root_key, num=3)

d_net = Discriminator()
g_net = Generator(Z_DIM)

d_state = create_train_state(d_net, jnp.ones(shape=(1, 64, 64, 1)), d_param_key, dropout_key, LR)
g_state = create_train_state(g_net, jnp.ones(shape=(1, Z_DIM)), g_param_key, None, LR)
# Out:
# Found 40000 files belonging to 1 classes.

# %% [markdown]
# ## 6. Training

# %%
num_steps_per_epoch = train_ds.cardinality().numpy() // EPOCHS
rng = jax.random.PRNGKey(0)

train_metrics = {
    'd_loss': Metrics.Mean(),
    'g_loss': Metrics.Mean(),
    'd_real_acc': Metrics.BinaryAccuracy(),
    'd_fake_acc': Metrics.BinaryAccuracy(),
    'g_acc': Metrics.BinaryAccuracy()
}

history = defaultdict(list)

rng, key = jax.random.split(rng)
real_labels = jnp.ones(shape=(BATCH_SIZE, 1))
real_noisy_labels = real_labels + NOISE_PARAM * jax.random.normal(rng, shape=real_labels.shape)
fake_labels = jnp.zeros(shape=(BATCH_SIZE, 1))
fake_noisy_labels = fake_labels - NOISE_PARAM * jax.random.normal(key, shape=fake_labels.shape)

# %%
prev_time = time.time()


for step, real_imgs in enumerate(train_ds.as_numpy_iterator()):
    rng, key = jax.random.split(rng)
    
    latents = jax.random.normal(rng, shape=(2, BATCH_SIZE, Z_DIM))
    # fake_imgs = generate_imgs(g_state, latents[0])

    # Update discriminator
    
    d_state, g_state = train_disciminator(d_state, g_state, latents[0], real_imgs, real_noisy_labels, fake_noisy_labels)
    # d_state = train_disciminator(d_state, fake_imgs, fake_noisy_labels)

    # Update generator
    d_state, g_state = train_generator(d_state, g_state, latents[1], real_labels)

    # calculate train metrics every epoch
    if (step + 1) % num_steps_per_epoch == 0:
        # Clear metrics
        
        test_batch = train_ds.take(int(BATCH_SIZE / 10))
        
        for test_imgs in test_batch.as_numpy_iterator():
            
            rng, key = jax.random.split(rng)
            latents_test = jax.random.normal(rng, shape=(BATCH_SIZE, Z_DIM))
            fake_imgs = generate_imgs(g_state, latents_test)    
            
            outputs = compute_metrics(d_state=d_state, g_state=g_state, 
                                      fake_imgs=fake_imgs, real_imgs=real_imgs, 
                                      real_labels=real_labels, fake_labels=fake_labels)

            d_loss, g_loss, real_preds, fake_preds = outputs

            train_metrics['d_loss'].update_state(d_loss)
            train_metrics['g_loss'].update_state(g_loss)
            train_metrics['d_fake_acc'].update_state(fake_labels, fake_preds)
            train_metrics['d_real_acc'].update_state(real_labels, real_preds)
            train_metrics['g_acc'].update_state(real_labels, fake_preds)

        for key, value in train_metrics.items():
            history[key].append(value.result().numpy())

        
        # Compute metrics
        display.clear_output(wait=True)
        
        curr_time = time.time()
        print('Epoch: {}\tepoch time {:.2f} min'.format((step + 1) // num_steps_per_epoch, (curr_time - prev_time) / 60))
        metrics = [f'{key}: {value.result().numpy():.4f} | ' for key, value in train_metrics.items()]
        print('\t', ''.join(metrics))
        display_imgs(fake_imgs)
        show_records(history)
        prev_time = curr_time
# Out:
# Epoch: 2	epoch time 0.17 min
# 	 d_loss: 1.6265 | g_loss: 0.3133 | d_real_acc: 1.0000 | d_fake_acc: 0.0000 | g_acc: 1.0000 |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#      12 d_state, g_state = train_disciminator(d_state, g_state, latents[0], real_imgs, real_noisy_labels, fake_noisy_labels)
#      13 # d_state = train_disciminator(d_state, fake_imgs, fake_noisy_labels)
#      14
#      15 # Update generator
# ---> 16 d_state, g_state = train_generator(d_state, g_state, latents[1], real_labels)
#      18 # calculate train metrics every epoch
#      19 if (step + 1) % num_steps_per_epoch == 0:
#      20     # Clear metrics
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/array.py:316, in ArrayImpl.__getitem__(self, idx)
#     314   return lax_numpy._rewriting_take(self, idx)
#     315 else:
# --> 316   return lax_numpy._rewriting_take(self, idx)
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:4077, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4068 def _rewriting_take(arr, idx, indices_are_sorted=False, unique_indices=False,
#    4069                     mode=None, fill_value=None):
#    4070   # Computes arr[idx].
#    (...)
#    4074   # For simplicity of generated primitives, we call lax.dynamic_slice in the
#    4075   # simplest cases: i.e. non-dynamic arrays indexed with integers and slices.
# -> 4077   if (result := _attempt_rewriting_take_via_slice(arr, idx, mode)) is not None:
#    4078     return result
#    4080   # TODO(mattjj,dougalm): expand dynamic shape indexing support
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:4064, in _attempt_rewriting_take_via_slice(arr, idx, mode)
#    4062 arr = lax.dynamic_slice(arr, start_indices=start_indices, slice_sizes=slice_sizes)
#    4063 if int_indices:
# -> 4064   arr = lax.squeeze(arr, tuple(int_indices))
#    4065 return arr
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/lax/lax.py:1311, in squeeze(array, dimensions)
#    1309 if not dimensions and isinstance(array, Array):
#    1310   return type_cast(Array, array)
# -> 1311 return squeeze_p.bind(array, dimensions=dimensions)
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/core.py:380, in Primitive.bind(self, *args, **params)
#     377 def bind(self, *args, **params):
#     378   assert (not config.jax_enable_checks or
#     379           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 380   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/core.py:383, in Primitive.bind_with_trace(self, trace, args, params)
#     382 def bind_with_trace(self, trace, args, params):
# --> 383   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     384   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/core.py:790, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     789 def process_primitive(self, primitive, tracers, params):
# --> 790   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/dispatch.py:143, in apply_primitive(prim, *args, **params)
#     139   msg = pjit._device_assignment_mismatch_error(
#     140       prim.name, fails, args, 'jit', arg_names)
#     141   raise ValueError(msg) from None
# --> 143 return compiled_fun(*args)
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/dispatch.py:226, in xla_primitive_callable.<locals>.<lambda>(*args, **kw)
#     222 compiled = _xla_callable_uncached(
#     223     lu.wrap_init(prim_fun), prim.name, donated_invars, False, in_avals,
#     224     orig_in_shardings)
#     225 if not prim.multiple_results:
# --> 226   return lambda *args, **kw: compiled(*args, **kw)[0]
#     227 else:
#     228   return compiled
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/GDL_JAX/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1346, in ExecuteReplicated.__call__(self, *args)
#    1341   self._handle_token_bufs(
#    1342       results.disassemble_prefix_into_single_device_arrays(
#    1343           len(self.ordered_effects)),
#    1344       results.consume_token())
#    1345 else:
# -> 1346   results = self.xla_executable.execute_sharded(input_bufs)
#    1347 if dispatch.needs_check_special():
#    1348   out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:
